# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.model_selection import train_test_split
import category_encoders as ce
from catboost import CatBoostRegressor, Pool
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import cross_val_score

from sklearn.pipeline import make_pipeline

from xgboost.sklearn import XGBRegressor
from sklearn.model_selection import GridSearchCV

train_raw, test_raw = pd.read_csv('~/Downloads/house-pricing/train.csv'), pd.read_csv('~/Downloads/house-pricing/test.csv')

# %%
categorical = ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
              'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
              'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu',
              'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
# Street, Utilities, Condition2, RoofMatl: bad repartition
# Alley, PoolQC: most are missing

numerical = ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
             'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF',
             'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'MiscVal', 'OverallCond', 'OverallQual']
# MasVnrArea, BsmtFinSF1, 2ndFlrSF, LowQualFinSF, PoolArea: Had a lot of 0.0
date_related = ['GarageYrBlt', 'MoSold', 'YrSold']
boolean = ['CentralAir']
target = 'SalePrice'
to_drop = ['Id', 'PoolArea', 'PoolQC', 'YearBuilt', 'YearRemodAdd']

assert len(categorical )+ len(numerical) + len(date_related) + len(boolean) + len(to_drop) + 1 == train_raw.shape[1]
assert set(categorical + numerical + date_related + boolean + [target] + to_drop) == set(train_raw.columns)

# %%
train = train_raw.copy()
train['TotalArea'] = train['1stFlrSF'] + train['2ndFlrSF'] + train['OpenPorchSF']
train['LivibleRatio'] = train['1stFlrSF'] / train['LotArea']
train['HasMasVnr'] = train['MasVnrArea'] == 0
train['BuildingAge'] = 2020 - train['YearBuilt']
train['LastRemodling'] = 2020 - train['YearRemodAdd']
train = train.drop(columns=to_drop, axis=1)

# %%
train[numerical + date_related] = train[numerical + date_related].fillna(0)

features = ['Street', 'OverallQual', 'BsmtQual', 'FullBath', 'GarageCars', 'LastRemodling', 'BuildingAge', 'MiscVal', '2ndFlrSF', 'LotArea']
X_train, X_test = train_test_split(train, test_size=0.3)
Y_train, Y_test = np.log(X_train.pop(target)), np.log(X_test.pop(target))


encoder = ce.TargetEncoder(cols=categorical + boolean)
encoder.fit(X_train, Y_train)
X_train, X_test = encoder.transform(X_train, Y_train), encoder.transform(X_test, Y_test)
# Out:
# /home/amine/miniconda3/envs/dev/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
model = RandomForestRegressor(n_jobs=-1)
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
def rmse():
    train_pred, test_pred  = model.predict(X_train), model.predict(X_test)
    train_mse, test_mse = mean_squared_error(train_pred, Y_train), mean_squared_error(test_pred, Y_test)
    return np.sqrt(train_mse), np.sqrt(test_mse) 

rmse()
# Out:
# (0.05427861580566846, 0.15703645389676105)

# %%
param_dist = {'objective':'reg:squarederror', 'n_estimators':100, 'reg_lambda': 3, 'max_depth':3, 'colsample_bynode': 0.2, }
model = XGBRegressor(**param_dist)
model.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_test, Y_test)], eval_metric="rmse")
# Out:
# [0]	validation_0-rmse:8.07415	validation_1-rmse:8.08828
# [1]	validation_0-rmse:5.65679	validation_1-rmse:5.66786
# [2]	validation_0-rmse:3.96522	validation_1-rmse:3.97187
# [3]	validation_0-rmse:2.78180	validation_1-rmse:2.78211
# [4]	validation_0-rmse:1.95386	validation_1-rmse:1.95524
# [5]	validation_0-rmse:1.37493	validation_1-rmse:1.37416
# [6]	validation_0-rmse:0.97144	validation_1-rmse:0.97055
# [7]	validation_0-rmse:0.69156	validation_1-rmse:0.68881
# [8]	validation_0-rmse:0.49882	validation_1-rmse:0.49665
# [9]	validation_0-rmse:0.36650	validation_1-rmse:0.36838
# [10]	validation_0-rmse:0.27741	validation_1-rmse:0.28400
# [11]	validation_0-rmse:0.22026	validation_1-rmse:0.23210
# [12]	validation_0-rmse:0.18445	validation_1-rmse:0.20229
# [13]	validation_0-rmse:0.16164	validation_1-rmse:0.18381
# [14]	validation_0-rmse:0.14871	validation_1-rmse:0.17525
# [15]	validation_0-rmse:0.14068	validation_1-rmse:0.17069
# [16]	validation_0-rmse:0.13550	validation_1-rmse:0.16672
# [17]	validation_0-rmse:0.13239	validation_1-rmse:0.16502
# [18]	validation_0-rmse:0.12919	validation_1-rmse:0.16245
# [19]	validation_0-rmse:0.12674	validation_1-rmse:0.16020
# [20]	validation_0-rmse:0.12470	validation_1-rmse:0.15866
# [21]	validation_0-rmse:0.12275	validation_1-rmse:0.15691
# [22]	validation_0-rmse:0.12166	validation_1-rmse:0.15593
# [23]	validation_0-rmse:0.12033	validation_1-rmse:0.15603
# [24]	validation_0-rmse:0.11824	validation_1-rmse:0.15389
# [25]	validation_0-rmse:0.11692	validation_1-rmse:0.15343
# [26]	validation_0-rmse:0.11560	validation_1-rmse:0.15255
# [27]	validation_0-rmse:0.11474	validation_1-rmse:0.15249
# [28]	validation_0-rmse:0.11352	validation_1-rmse:0.15161
# [29]	validation_0-rmse:0.11262	validation_1-rmse:0.15117
# [30]	validation_0-rmse:0.11142	validation_1-rmse:0.15098
# [31]	validation_0-rmse:0.11073	validation_1-rmse:0.15061
# [32]	validation_0-rmse:0.11017	validation_1-rmse:0.15007
# [33]	validation_0-rmse:0.10893	validation_1-rmse:0.14930
# [34]	validation_0-rmse:0.10838	validation_1-rmse:0.14868
# [35]	validation_0-rmse:0.10768	validation_1-rmse:0.14907
# [36]	validation_0-rmse:0.10701	validation_1-rmse:0.14929
# [37]	validation_0-rmse:0.10611	validation_1-rmse:0.14864
# [38]	validation_0-rmse:0.10520	validation_1-rmse:0.14785
# [39]	validation_0-rmse:0.10461	validation_1-rmse:0.14791
# [40]	validation_0-rmse:0.10399	validation_1-rmse:0.14764
# [41]	validation_0-rmse:0.10343	validation_1-rmse:0.14812
# [42]	validation_0-rmse:0.10266	validation_1-rmse:0.14769
# [43]	validation_0-rmse:0.10200	validation_1-rmse:0.14757
# [465]	validation_0-rmse:0.04000	validation_1-rmse:0.13802
# [466]	validation_0-rmse:0.03982	validation_1-rmse:0.13813
# [467]	validation_0-rmse:0.03975	validation_1-rmse:0.13829
# [468]	validation_0-rmse:0.03962	validation_1-rmse:0.13837
# [469]	validation_0-rmse:0.03957	validation_1-rmse:0.13839
# [470]	validation_0-rmse:0.03947	validation_1-rmse:0.13838
# [471]	validation_0-rmse:0.03941	validation_1-rmse:0.13836
# [472]	validation_0-rmse:0.03936	validation_1-rmse:0.13840
# [473]	validation_0-rmse:0.03934	validation_1-rmse:0.13852
# [474]	validation_0-rmse:0.03930	validation_1-rmse:0.13850
# [475]	validation_0-rmse:0.03923	validation_1-rmse:0.13849
# [476]	validation_0-rmse:0.03914	validation_1-rmse:0.13850
# [477]	validation_0-rmse:0.03913	validation_1-rmse:0.13853
# [478]	validation_0-rmse:0.03908	validation_1-rmse:0.13842
# [479]	validation_0-rmse:0.03905	validation_1-rmse:0.13847
# [480]	validation_0-rmse:0.03896	validation_1-rmse:0.13860
# [481]	validation_0-rmse:0.03893	validation_1-rmse:0.13854
# [482]	validation_0-rmse:0.03891	validation_1-rmse:0.13856
# [483]	validation_0-rmse:0.03887	validation_1-rmse:0.13835
# [484]	validation_0-rmse:0.03883	validation_1-rmse:0.13841
# [485]	validation_0-rmse:0.03882	validation_1-rmse:0.13841
# [486]	validation_0-rmse:0.03875	validation_1-rmse:0.13844
# [487]	validation_0-rmse:0.03869	validation_1-rmse:0.13842
# [488]	validation_0-rmse:0.03864	validation_1-rmse:0.13845
# [489]	validation_0-rmse:0.03859	validation_1-rmse:0.13849
# [490]	validation_0-rmse:0.03853	validation_1-rmse:0.13845
# [491]	validation_0-rmse:0.03845	validation_1-rmse:0.13844
# [492]	validation_0-rmse:0.03820	validation_1-rmse:0.13841
# [493]	validation_0-rmse:0.03816	validation_1-rmse:0.13839
# [494]	validation_0-rmse:0.03809	validation_1-rmse:0.13837
# [495]	validation_0-rmse:0.03804	validation_1-rmse:0.13832
# [496]	validation_0-rmse:0.03798	validation_1-rmse:0.13828
# [497]	validation_0-rmse:0.03793	validation_1-rmse:0.13828
# [498]	validation_0-rmse:0.03790	validation_1-rmse:0.13824
# [499]	validation_0-rmse:0.03784	validation_1-rmse:0.13831
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=0.2, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=2,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=0.3, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# # 11.7 model

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.model_selection import train_test_split
import category_encoders as ce
from catboost import CatBoostRegressor, Pool
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler, PowerTransformer


from xgboost.sklearn import XGBRegressor
from sklearn.model_selection import GridSearchCV

# %%
train_raw, test_raw = pd.read_csv('~/Downloads/house-pricing/train.csv'), pd.read_csv('~/Downloads/house-pricing/test.csv')

# %%
# Street, Utilities, Condition2, RoofMatl: bad repartition
# Alley, PoolQC: most are missing


# MasVnrArea, BsmtFinSF1, 2ndFlrSF, LowQualFinSF, PoolArea: Had a lot of 0.0
date_related = ['GarageYrBlt', 'MoSold', 'YrSold']
boolean = ['CentralAir']
target = 'SalePrice'
to_drop = ['Id', 'PoolArea', 'PoolQC', 'YearBuilt', 'YearRemodAdd']

numerical = ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
             'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF',
             'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'MiscVal', 'OverallCond', 'OverallQual'] + date_related
categorical = ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
              'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
              'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu',
              'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']  + boolean

assert len(categorical )+ len(numerical) + len(to_drop) + 1 == train_raw.shape[1]
assert set(categorical + numerical + date_related + boolean + [target] + to_drop) == set(train_raw.columns)

discrete = []
for var in numerical:
    if len(train_raw[var].unique())<20:
        discrete.append(var)
        

# Missing values:
mostly_missing = list()
treshold = 0.8
for var in train_raw.columns:
    missing_prc =  train_raw[var].isna().mean()
    if missing_prc > treshold:
        mostly_missing.append(var)
        

# Dist and outliers for continuous features
continuous = [var for var in numerical if var not in discrete and var not in ['Id', 'SalePrice']]

# %%
train = train_raw.copy()
# train['TotalArea'] = train['1stFlrSF'] + train['2ndFlrSF']
train['LivibleRatio'] = train['1stFlrSF'] / train['LotArea']
train['HasMasVnr'] = train['MasVnrArea'] == 0
train['BuildingAge'] = 2020 - train['YearBuilt']
train['LastRemodling'] = 2020 - train['YearRemodAdd']
train['HasPool'] = train['PoolArea'] > 0
train['BuiltPercentage'] = train['1stFlrSF'] / train['LotArea']
train['DiffBuitSold'] = train['YearBuilt'] - train['YrSold']
train['AvrRoomSF'] = train['TotRmsAbvGrd'] / (train['1stFlrSF'] + train['2ndFlrSF'])
train['2ndfloorPercentage'] = train['2ndFlrSF'] / train['1stFlrSF']
train['HasBasment'] = train['TotalBsmtSF'] > 0
train['DiffRemodBuilt'] = train['YearRemodAdd'] - train['YearBuilt']


# to_drop += ['YrSold', ]


# train['TotalArea'] = train['1stFlrSF'] + train['2ndFlrSF'] + train['OpenPorchSF']
# train['LivibleRatio'] = train['1stFlrSF'] / train['LotArea']
# train['HasMasVnr'] = train['MasVnrArea'] == 0
# train['BuildingAge'] = 2020 - train['YearBuilt']
# train['LastRemodling'] = 2020 - train['YearRemodAdd']


engineered = ['TotalArea', 'LivibleRatio', 'HasMasVnr', 'BuildingAge', 'LastRemodling', 'HasPool', 'BuiltPercentage', 'DiffBuitSold', 'AvrRoomSF',
             '2ndfloorPercentage', 'HasBasment', 'DiffRemodBuilt']

to_normalize = ['DiffBuitSold', 'BuildingAge', 'LastRemodling', 'DiffRemodBuilt']
train = train.drop(columns=to_drop, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(train, train.SalePrice, test_size=0.2,
                                                    random_state=0)
X_train.pop(target), X_test.pop(target)

y_train, y_test = np.log(y_train), np.log(y_test)

# %%
# Dealing with missing values in continuous
# If most of the values are 0, then create seperate boolean column to indicate if 0, and replace the 0 values with median, then apply transformation

drop = True
keep_outliers = True
sensitivity = 2.9
for var in continuous:
    
    if ((X_train[var] == 0).sum() / X_train.shape[0]) > 0.3:
        X_train[var + 'Is0'] = X_train[var] == 0
        X_test[var + 'Is0'] = X_test[var] == 0
        if drop:
            X_train.pop(var), X_test.pop(var)
            continue
        else:
            mean = X_train[var][X_train[var] != 0].mean()
            X_train.loc[:, var] = X_train.loc[:, var].replace(0, mean)
            X_test.loc[:, var] = X_test.loc[:, var].replace(0, mean)
        
    
    transformer = PowerTransformer()
    transformer.fit(X_train[[var]])
    X_train[var], X_test[var] = transformer.transform(X_train[[var]]).flatten(), transformer.transform(X_test[[var]]).flatten()

    if not keep_outliers:
        mean, std = X_train[var].mean(), X_train[var].std()
        z_score = (X_train[var] - mean) / std
        X_train[var] = np.clip(X_train[var], - sensitivity * z_score, sensitivity * z_score)
# Out:
# <ipython-input-10-3f317315371c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var], X_test[var] = transformer.transform(X_train[[var]]).flatten(), transformer.transform(X_test[[var]]).flatten()
# <ipython-input-10-3f317315371c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var], X_test[var] = transformer.transform(X_train[[var]]).flatten(), transformer.transform(X_test[[var]]).flatten()
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# <ipython-input-10-3f317315371c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var], X_test[var] = transformer.transform(X_train[[var]]).flatten(), transformer.transform(X_test[[var]]).flatten()
# <ipython-input-10-3f317315371c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var], X_test[var] = transformer.transform(X_train[[var]]).flatten(), transformer.transform(X_test[[var]]).flatten()
# <ipython-input-10-3f317315371c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var], X_test[var] = transformer.transform(X_train[[var]]).flatten(), transformer.transform(X_test[[var]]).flatten()
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# <ipython-input-10-3f317315371c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var], X_test[var] = transformer.transform(X_train[[var]]).flatten(), transformer.transform(X_test[[var]]).flatten()
# <ipython-input-10-3f317315371c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var], X_test[var] = transformer.transform(X_train[[var]]).flatten(), transformer.transform(X_test[[var]]).flatten()
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# <ipython-input-10-3f317315371c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var + 'Is0'] = X_train[var] == 0
# <ipython-input-10-3f317315371c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[var + 'Is0'] = X_test[var] == 0
# /home/amine/miniconda3/envs/dev/lib/python3.8/site-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# <ipython-input-10-3f317315371c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[var], X_test[var] = transformer.transform(X_train[[var]]).flatten(), transformer.transform(X_test[[var]]).flatten()

# %%
# Missing values in continuous variables
# add variable indicating missingness + median imputation
for df in [X_train, X_test]:
    for var in ['LotFrontage', 'GarageYrBlt']:
        df[var+'_NA'] = np.where(df[var].isnull(), 1, 0)
        df[var].fillna(X_train[var].median(), inplace=True) 

for df in [X_train, X_test]:
    df.MasVnrArea.fillna(X_train.MasVnrArea.median(), inplace=True)
# Out:
# <ipython-input-11-efc4624e0805>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[var+'_NA'] = np.where(df[var].isnull(), 1, 0)
# /home/amine/miniconda3/envs/dev/lib/python3.8/site-packages/pandas/core/series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-efc4624e0805> in <module>
#       7
#       8 for df in [X_train, X_test]:
# ----> 9     df.MasVnrArea.fillna(X_train.MasVnrArea.median(), inplace=True)
#
# ~/miniconda3/envs/dev/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'MasVnrArea'

# %%
# Missing values in categorical data

# Adding missing label
for df in [X_train, X_test]:
    for var in categorical:
        df[var].fillna('Missing', inplace=True)

# Adding rare label
# treshold = 0.05
# def rare_imputation(variable):
#     # find frequent labels / discrete numbers
#     temp = X_train.groupby([variable])[variable].count()/np.float(len(X_train))
#     frequent_cat = [x for x in temp.loc[temp > treshold].index.values]
    
#     X_train.loc[:, variable] = np.where(X_train[variable].isin(frequent_cat), X_train[variable], 'Rare')
#     X_test.loc[:, variable] = np.where(X_test[variable].isin(frequent_cat), X_test[variable], 'Rare')
    
# # find unfrequent labels in categorical variables
# for var in categorical:
#     rare_imputation(var)

# %%
# Encoding
encoder = ce.TargetEncoder(cols=categorical)
encoder.fit(X_train, y_train)
X_train, X_test = encoder.transform(X_train), encoder.transform(X_test)
# Out:
# /home/amine/miniconda3/envs/dev/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
# Scaling
scaler = RobustScaler() # create an instance
scaler.fit(X_train)
X_train, X_test = scaler.transform(X_train), scaler.transform(X_test)

# %%
param_dist = {'objective':'reg:squarederror', 'n_estimators':1_000, 'reg_lambda': 0.4, 'max_depth':1, 'colsample_bynode': 0.2, }
model = XGBRegressor(**param_dist)
model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], eval_metric="rmse")
# Out:
# [0]	validation_0-rmse:8.07680	validation_1-rmse:8.08716
# [1]	validation_0-rmse:5.65918	validation_1-rmse:5.66671
# [2]	validation_0-rmse:3.96758	validation_1-rmse:3.97648
# [3]	validation_0-rmse:2.78435	validation_1-rmse:2.79246
# [4]	validation_0-rmse:1.95751	validation_1-rmse:1.96522
# [5]	validation_0-rmse:1.38102	validation_1-rmse:1.38674
# [6]	validation_0-rmse:0.97929	validation_1-rmse:0.98269
# [7]	validation_0-rmse:0.70278	validation_1-rmse:0.70544
# [8]	validation_0-rmse:0.51427	validation_1-rmse:0.51355
# [9]	validation_0-rmse:0.38903	validation_1-rmse:0.38668
# [10]	validation_0-rmse:0.30630	validation_1-rmse:0.30040
# [11]	validation_0-rmse:0.25342	validation_1-rmse:0.24758
# [12]	validation_0-rmse:0.22254	validation_1-rmse:0.21548
# [13]	validation_0-rmse:0.20261	validation_1-rmse:0.19466
# [14]	validation_0-rmse:0.19036	validation_1-rmse:0.18224
# [15]	validation_0-rmse:0.18196	validation_1-rmse:0.17300
# [16]	validation_0-rmse:0.17735	validation_1-rmse:0.16935
# [17]	validation_0-rmse:0.17263	validation_1-rmse:0.16564
# [18]	validation_0-rmse:0.16919	validation_1-rmse:0.16334
# [19]	validation_0-rmse:0.16583	validation_1-rmse:0.16127
# [20]	validation_0-rmse:0.16382	validation_1-rmse:0.16039
# [21]	validation_0-rmse:0.16085	validation_1-rmse:0.16065
# [22]	validation_0-rmse:0.15890	validation_1-rmse:0.15868
# [23]	validation_0-rmse:0.15714	validation_1-rmse:0.15653
# [24]	validation_0-rmse:0.15557	validation_1-rmse:0.15466
# [25]	validation_0-rmse:0.15351	validation_1-rmse:0.15379
# [26]	validation_0-rmse:0.15046	validation_1-rmse:0.15083
# [27]	validation_0-rmse:0.14939	validation_1-rmse:0.15053
# [28]	validation_0-rmse:0.14702	validation_1-rmse:0.14890
# [29]	validation_0-rmse:0.14591	validation_1-rmse:0.14873
# [30]	validation_0-rmse:0.14477	validation_1-rmse:0.14847
# [31]	validation_0-rmse:0.14286	validation_1-rmse:0.14694
# [32]	validation_0-rmse:0.14176	validation_1-rmse:0.14576
# [33]	validation_0-rmse:0.14054	validation_1-rmse:0.14546
# [34]	validation_0-rmse:0.13948	validation_1-rmse:0.14591
# [35]	validation_0-rmse:0.13861	validation_1-rmse:0.14597
# [36]	validation_0-rmse:0.13755	validation_1-rmse:0.14489
# [37]	validation_0-rmse:0.13691	validation_1-rmse:0.14440
# [38]	validation_0-rmse:0.13577	validation_1-rmse:0.14404
# [39]	validation_0-rmse:0.13524	validation_1-rmse:0.14363
# [40]	validation_0-rmse:0.13414	validation_1-rmse:0.14291
# [41]	validation_0-rmse:0.13354	validation_1-rmse:0.14291
# [650]	validation_0-rmse:0.08619	validation_1-rmse:0.11524
# [651]	validation_0-rmse:0.08617	validation_1-rmse:0.11512
# [652]	validation_0-rmse:0.08615	validation_1-rmse:0.11520
# [653]	validation_0-rmse:0.08613	validation_1-rmse:0.11517
# [654]	validation_0-rmse:0.08611	validation_1-rmse:0.11515
# [655]	validation_0-rmse:0.08609	validation_1-rmse:0.11528
# [656]	validation_0-rmse:0.08607	validation_1-rmse:0.11529
# [657]	validation_0-rmse:0.08605	validation_1-rmse:0.11534
# [658]	validation_0-rmse:0.08604	validation_1-rmse:0.11532
# [659]	validation_0-rmse:0.08602	validation_1-rmse:0.11531
# [660]	validation_0-rmse:0.08600	validation_1-rmse:0.11532
# [661]	validation_0-rmse:0.08598	validation_1-rmse:0.11531
# [662]	validation_0-rmse:0.08596	validation_1-rmse:0.11530
# [663]	validation_0-rmse:0.08594	validation_1-rmse:0.11531
# [664]	validation_0-rmse:0.08592	validation_1-rmse:0.11527
# [665]	validation_0-rmse:0.08590	validation_1-rmse:0.11522
# [666]	validation_0-rmse:0.08589	validation_1-rmse:0.11511
# [667]	validation_0-rmse:0.08587	validation_1-rmse:0.11509
# [668]	validation_0-rmse:0.08585	validation_1-rmse:0.11508
# [669]	validation_0-rmse:0.08583	validation_1-rmse:0.11506
# [670]	validation_0-rmse:0.08581	validation_1-rmse:0.11503
# [671]	validation_0-rmse:0.08579	validation_1-rmse:0.11510
# [672]	validation_0-rmse:0.08578	validation_1-rmse:0.11504
# [673]	validation_0-rmse:0.08576	validation_1-rmse:0.11507
# [674]	validation_0-rmse:0.08574	validation_1-rmse:0.11504
# [675]	validation_0-rmse:0.08572	validation_1-rmse:0.11511
# [676]	validation_0-rmse:0.08571	validation_1-rmse:0.11516
# [677]	validation_0-rmse:0.08569	validation_1-rmse:0.11524
# [678]	validation_0-rmse:0.08568	validation_1-rmse:0.11516
# [679]	validation_0-rmse:0.08566	validation_1-rmse:0.11525
# [680]	validation_0-rmse:0.08564	validation_1-rmse:0.11532
# [681]	validation_0-rmse:0.08562	validation_1-rmse:0.11523
# [682]	validation_0-rmse:0.08560	validation_1-rmse:0.11522
# [683]	validation_0-rmse:0.08559	validation_1-rmse:0.11527
# [684]	validation_0-rmse:0.08557	validation_1-rmse:0.11515
# [685]	validation_0-rmse:0.08555	validation_1-rmse:0.11515
# [686]	validation_0-rmse:0.08553	validation_1-rmse:0.11524
# [687]	validation_0-rmse:0.08551	validation_1-rmse:0.11529
# [688]	validation_0-rmse:0.08549	validation_1-rmse:0.11529
# [689]	validation_0-rmse:0.08547	validation_1-rmse:0.11537
# [690]	validation_0-rmse:0.08546	validation_1-rmse:0.11545
# [691]	validation_0-rmse:0.08544	validation_1-rmse:0.11536
# [692]	validation_0-rmse:0.08542	validation_1-rmse:0.11538
# [693]	validation_0-rmse:0.08540	validation_1-rmse:0.11537
# [694]	validation_0-rmse:0.08538	validation_1-rmse:0.11538
# [695]	validation_0-rmse:0.08536	validation_1-rmse:0.11544
# [696]	validation_0-rmse:0.08535	validation_1-rmse:0.11540
# [977]	validation_0-rmse:0.08104	validation_1-rmse:0.11567
# [978]	validation_0-rmse:0.08102	validation_1-rmse:0.11573
# [979]	validation_0-rmse:0.08101	validation_1-rmse:0.11572
# [980]	validation_0-rmse:0.08099	validation_1-rmse:0.11573
# [981]	validation_0-rmse:0.08098	validation_1-rmse:0.11571
# [982]	validation_0-rmse:0.08097	validation_1-rmse:0.11571
# [983]	validation_0-rmse:0.08096	validation_1-rmse:0.11584
# [984]	validation_0-rmse:0.08094	validation_1-rmse:0.11581
# [985]	validation_0-rmse:0.08093	validation_1-rmse:0.11580
# [986]	validation_0-rmse:0.08092	validation_1-rmse:0.11580
# [987]	validation_0-rmse:0.08091	validation_1-rmse:0.11587
# [988]	validation_0-rmse:0.08089	validation_1-rmse:0.11585
# [989]	validation_0-rmse:0.08088	validation_1-rmse:0.11591
# [990]	validation_0-rmse:0.08087	validation_1-rmse:0.11594
# [991]	validation_0-rmse:0.08085	validation_1-rmse:0.11592
# [992]	validation_0-rmse:0.08084	validation_1-rmse:0.11596
# [993]	validation_0-rmse:0.08083	validation_1-rmse:0.11594
# [994]	validation_0-rmse:0.08081	validation_1-rmse:0.11588
# [995]	validation_0-rmse:0.08080	validation_1-rmse:0.11584
# [996]	validation_0-rmse:0.08079	validation_1-rmse:0.11589
# [997]	validation_0-rmse:0.08077	validation_1-rmse:0.11578
# [998]	validation_0-rmse:0.08076	validation_1-rmse:0.11592
# [999]	validation_0-rmse:0.08075	validation_1-rmse:0.11587
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=0.2, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=1,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=0.4, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
class XGBModel:
    def __init__(self, drop_continous=False, keep_continous_outliers=False, outliers_sensitivity=2.8):
        self.drop_continuous = drop_continous
        self.keep_continuous_outliers = keep_continuous_outliers
        self.outliers_sensitivity = outliers_sensitivit
    
    def _continuous_engineering():
        drop = self.drop_continuous
        keep_outliers = self.keep_continuous_outliers
        sensitivity = 2.9
        for var in continuous:

            if ((X_train[var] == 0).sum() / X_train.shape[0]) > 0.3:
                X_train[var + 'Is0'] = X_train[var] == 0
                X_test[var + 'Is0'] = X_test[var] == 0
                if drop:
                    X_train.pop(var), X_test.pop(var)
                    continue
                else:
                    mean = X_train[var][X_train[var] != 0].mean()
                    X_train.loc[:, var] = X_train.loc[:, var].replace(0, mean)
                    X_test.loc[:, var] = X_test.loc[:, var].replace(0, mean)


            transformer = PowerTransformer()
            transformer.fit(X_train[[var]])
            X_train[var], X_test[var] = transformer.transform(X_train[[var]]).flatten(), transformer.transform(X_test[[var]]).flatten()

            if not keep_outliers:
                mean, std = X_train[var].mean(), X_train[var].std()
                z_score = (X_train[var] - mean) / std
                X_train[var] = np.clip(X_train[var], - sensitivity * z_score, sensitivity * z_score)
